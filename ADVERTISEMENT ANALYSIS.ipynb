# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\Brandulox\Desktop\DATA SETS\advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.size
# Out:
# 800

# %% [markdown]
# Observation - The above data is for dollars(in thousands of dollars) spent on advertising in TV, Radio and Newspaper Channel sales-The sales data shows sales of single project(in thousands of items) in market.

# %%
#Checking null values
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# Observation - There is no null values present in the given dataset

# %%
#Checking data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.shape
# Out:
# (200, 4)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#VChecking the columns
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# ## SUMMARY STATISTICS

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Observation - There is huge difference between 75% and maximum in colums newspaper, So possibly outliers present.
#
# The minimum sales is 1.60 and the maximum is 27.
#
# Std is maximum in TV

# %%
# Checking correlation

df_cor=df.corr()
df_cor
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
# Use heatmap to check correlation for better understanding.
sns.heatmap(data = df_cor, annot = True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# Observation - We can see there is little higj correlation between tv and sales, and very low correlation between newspaper and sales.

# %% [markdown]
# ## Data Visualization
#
# Univirate Analysis

# %%
#Checking total amount spent tv, radio ands newspaper
print("Amount spent on radio:",df["Radio"].sum())
print("Amount spent on Newspaper:",df["Newspaper"].sum())
print("Amount spent on Sales:",df["Sales"].sum())
print("Amount spent on TV:",df["TV"].sum())
# Out:
# Amount spent on radio: 4652.800000000001
# Amount spent on Newspaper: 6110.799999999999
# Amount spent on Sales: 3026.1000000000004
# Amount spent on TV: 29408.5

# %% [markdown]
# Observation - We can see highest amount spent on TV

# %%
df["TV"].plot.hist(bins=21)
plt.title("TV Histogram")
plt.show()

# %%
df["Radio"].plot.hist(bins=21)
plt.title("Radio Histogram")
plt.show()

# %%
df["Newspaper"].plot.hist(bins=21)
plt.title("Newspaper Histogram")
plt.show()

# %%
df["Sales"].plot.hist(bins=21)
plt.title("Sales Histogram")
plt.show()

# %%
sns.set (style="whitegrid")
sns.violinplot(df["TV"])
plt.show()

# %% [markdown]
# Observation - We can see avarage 180 to 240 (in thousand od dollars) spent on advertising on the products.

# %%
sns.set (style="whitegrid")
sns.violinplot(df["Radio"])
plt.show()

# %%
sns.set (style="whitegrid")
sns.violinplot(df["Newspaper"])
plt.show()

# %%
sns.set (style="whitegrid")
sns.violinplot(df["Sales"])
plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
# Checking Relationship between advertising channel and sale using scatter plot and pair plot
sns.set(style = "darkgrid")
plt.scatter(df["TV"], df["Sales"])
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("Scatter plot of TV vs Sales")
plt.show()

# %%
sns.set(style = "darkgrid")
plt.scatter(df["Radio"], df["Sales"])
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.title("Scatter plot of Radio vs Sales")
plt.show()

# %%
sns.set(style = "darkgrid")
plt.scatter(df["Newspaper"], df["Sales"])
plt.xlabel("Newspapers")
plt.ylabel("Sales")
plt.title("Scatter plot of Newspaper vs Sales")
plt.show()

# %%
sns.pairplot(df, x_vars = ["TV", "Radio", "Newspaper"], y_vars = "Sales", size = 9, aspect = 0.7, kind = "reg" )

# %% [markdown]
# ## PLOT OUTLIERS

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df["TV"].plot.box()
# Out:
# <Axes: >

# %%
df["Radio"].plot.box()
# Out:
# <Axes: >

# %%
df["Newspaper"].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# Observation  - possibly outliers present in newspaper column.

# %% [markdown]
# ## CHECK THE DISTRIBUTION OF SKEWNEWSS

# %%
collist = df.columns.values
ncol = 10
nrow = 5

plt.figure(figsize = (20,10))
for i in range (0, len(collist)):
    plt.subplot(nrow, ncol, i+1)
    sns.distplot(df[collist[i]], color = "brown")
    plt.tight_layout()

# %%
# Checking skewnewss
df.skew()
# Out:
# TV          -0.069853
# Radio        0.094175
# Newspaper    0.894720
# Sales       -0.073739
# dtype: float64

# %%
# Treating skewness via Log method

for col in df.columns:
    if df[col].skew() > 0.55:
        df[col] = np.log1p(df[col])

# %%
# Checking Skewness again
df.skew()
# Out:
# TV          -0.069853
# Radio        0.094175
# Newspaper   -0.799875
# Sales       -0.073739
# dtype: float64

# %%
for i in df.columns:
    sns.displot(df[i])
    plt.show()

# %% [markdown]
# ## REMOVE OUTLIERS

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
z
# Out:
#            TV     Radio  Newspaper     Sales
# 0    0.969852  0.981522   1.270548  1.322319
# 1    1.197376  1.082808   0.784008  0.897515
# 2    1.516155  1.528463   1.272195  0.593948
# 3    0.052050  1.217855   1.079221  0.259834
# 4    0.394182  0.841614   1.077274  0.525455
# ..        ...       ...        ...       ...
# 195  1.270941  1.321031   0.530505  1.428757
# 196  0.617035  1.240003   1.093193  0.214489
# 197  0.349810  0.942899   1.332444  0.062706
# 198  1.594565  1.265121   1.220018  1.967398
# 199  0.993206  0.990165   1.019319  0.620320
#
# [200 rows x 4 columns]

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([33], dtype=int64), array([2], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print (df.shape)
# Out:
# (200, 4)

# %%
print(df_new.shape)
# Out:
# (199, 4)

# %% [markdown]
# Observation  - Now we can see one row removed from dataset due to outlier

# %%
## From our Analysis investing in TV advertisement contributed more to our sales.
I would advise we
